# %%
import random

class SilentTeacher:
    def __init__(self):
        self.encapsulamiento_exercises = [
            {
                "exercise": "Crea una clase 'CuentaBancaria' con un atributo privado 'saldo' y métodos para depositar y retirar dinero. Asegúrate de que el saldo no pueda ser negativo al retirar.",
                "solution": "class CuentaBancaria:\n    def __init__(self):\n        self.__saldo = 0\n    def depositar(self, cantidad):\n        self.__saldo += cantidad\n    def retirar(self, cantidad):\n        if cantidad <= self.__saldo:\n            self.__saldo -= cantidad"
            },
            {
                "exercise": "Define una clase 'Libro' que tenga un atributo privado 'titulo' y un método para mostrar el título. Usa un getter para acceder al título.",
                "solution": "class Libro:\n    def __init__(self, titulo):\n        self.__titulo = titulo\n    def get_titulo(self):\n        return self.__titulo"
            },
            {
                "exercise": "Crea una clase 'Persona' con atributos privados 'nombre' y 'edad'. Implementa métodos 'get_nombre' y 'set_nombre', y 'get_edad' y 'set_edad'.",
                "solution": "class Persona:\n    def __init__(self, nombre, edad):\n        self.__nombre = nombre\n        self.__edad = edad\n    def get_nombre(self):\n        return self.__nombre\n    def set_nombre(self, nombre):\n        self.__nombre = nombre\n    def get_edad(self):\n        return self.__edad\n    def set_edad(self, edad):\n        self.__edad = edad"
            },
            {
                "exercise": "Implementa una clase 'Coche' que tenga atributos privados 'marca' y 'modelo', y métodos para mostrar información del coche.",
                "solution": "class Coche:\n    def __init__(self, marca, modelo):\n        self.__marca = marca\n        self.__modelo = modelo\n    def mostrar_info(self):\n        return f'Marca: {self.__marca}, Modelo: {self.__modelo}'"
            },
            {
                "exercise": "Crea una clase 'Estudiante' que tenga un atributo privado 'notas' (lista de enteros) y un método para calcular la media de las notas.",
                "solution": "class Estudiante:\n    def __init__(self):\n        self.__notas = []\n    def agregar_nota(self, nota):\n        self.__notas.append(nota)\n    def calcular_media(self):\n        return sum(self.__notas) / len(self.__notas) if self.__notas else 0"
            },
            {
                "exercise": "Define una clase 'Rectangle' con atributos privados 'ancho' y 'alto'. Implementa un método que calcule el área del rectángulo.",
                "solution": "class Rectangle:\n    def __init__(self, ancho, alto):\n        self.__ancho = ancho\n        self.__alto = alto\n    def calcular_area(self):\n        return self.__ancho * self.__alto"
            },
            {
                "exercise": "Crea una clase 'Factura' con un atributo privado 'total' y métodos para agregar items y calcular el total.",
                "solution": "class Factura:\n    def __init__(self):\n        self.__total = 0\n    def agregar_item(self, precio):\n        self.__total += precio\n    def calcular_total(self):\n        return self.__total"
            },
            {
                "exercise": "Implementa una clase 'CuentaAhorro' que herede de 'CuentaBancaria' y añada un atributo privado 'interes' con un método para calcular el interés sobre el saldo.",
                "solution": "class CuentaAhorro(CuentaBancaria):\n    def __init__(self, interes):\n        super().__init__()\n        self.__interes = interes\n    def calcular_interes(self):\n        return self.__saldo * self.__interes"
            },
            {
                "exercise": "Define una clase 'Empleado' con atributos privados 'nombre' y 'salario'. Implementa un método que permita aumentar el salario.",
                "solution": "class Empleado:\n    def __init__(self, nombre, salario):\n        self.__nombre = nombre\n        self.__salario = salario\n    def aumentar_salario(self, cantidad):\n        self.__salario += cantidad"
            },
            {
                "exercise": "Crea una clase 'Producto' que tenga un atributo privado 'precio'. Implementa un método que aplique un descuento al precio.",
                "solution": "class Producto:\n    def __init__(self, precio):\n        self.__precio = precio\n    def aplicar_descuento(self, porcentaje):\n        self.__precio -= self.__precio * (porcentaje / 100)"
            }
        ]

        self.abstraccion_exercises = [
            {
                "exercise": "Crea una clase abstracta 'Forma' con un método abstracto 'calcular_area'. Luego, crea subclases 'Circulo' y 'Cuadrado' que implementen este método.",
                "solution": "from abc import ABC, abstractmethod\nclass Forma(ABC):\n    @abstractmethod\n    def calcular_area(self):\n        pass\nclass Circulo(Forma):\n    def __init__(self, radio):\n        self.radio = radio\n    def calcular_area(self):\n        return 3.14 * (self.radio ** 2)\nclass Cuadrado(Forma):\n    def __init__(self, lado):\n        self.lado = lado\n    def calcular_area(self):\n        return self.lado ** 2"
            },
            {
                "exercise": "Define una clase abstracta 'Animal' con un método abstracto 'hacer_sonido'. Crea subclases 'Perro' y 'Gato' que implementen este método.",
                "solution": "from abc import ABC, abstractmethod\nclass Animal(ABC):\n    @abstractmethod\n    def hacer_sonido(self):\n        pass\nclass Perro(Animal):\n    def hacer_sonido(self):\n        return 'Guau'\nclass Gato(Animal):\n    def hacer_sonido(self):\n        return 'Miau'"
            },
            {
                "exercise": "Crea una clase abstracta 'Vehiculo' con un método abstracto 'moverse'. Luego, implementa las subclases 'Bicicleta' y 'Coche'.",
                "solution": "from abc import ABC, abstractmethod\nclass Vehiculo(ABC):\n    @abstractmethod\n    def moverse(self):\n        pass\nclass Bicicleta(Vehiculo):\n    def moverse(self):\n        return 'La bicicleta se mueve'\nclass Coche(Vehiculo):\n    def moverse(self):\n        return 'El coche se mueve'"
            },
            {
                "exercise": "Define una clase abstracta 'Empleado' con un método abstracto 'calcular_sueldo'. Crea subclases 'EmpleadoTiempoCompleto' y 'EmpleadoPorHora'.",
                "solution": "from abc import ABC, abstractmethod\nclass Empleado(ABC):\n    @abstractmethod\n    def calcular_sueldo(self):\n        pass\nclass EmpleadoTiempoCompleto(Empleado):\n    def __init__(self, salario):\n        self.salario = salario\n    def calcular_sueldo(self):\n        return self.salario\nclass EmpleadoPorHora(Empleado):\n    def __init__(self, tarifa, horas):\n        self.tarifa = tarifa\n        self.horas = horas\n    def calcular_sueldo(self):\n        return self.tarifa * self.horas"
            },
            {
                "exercise": "Crea una clase abstracta 'Juego' con un método abstracto 'iniciar_juego'. Luego, crea subclases 'Aventura' y 'Estrategia'.",
                "solution": "from abc import ABC, abstractmethod\nclass Juego(ABC):\n    @abstractmethod\n    def iniciar_juego(self):\n        pass\nclass Aventura(Juego):\n    def iniciar_juego(self):\n        return 'Iniciando juego de aventura'\nclass Estrategia(Juego):\n    def iniciar_juego(self):\n        return 'Iniciando juego de estrategia'"
            },
            {
                "exercise": "Define una clase abstracta 'Edificio' con un método abstracto 'calcular_area_total'. Implementa subclases 'Casa' y 'Apartamento'.",
                "solution": "from abc import ABC, abstractmethod\nclass Edificio(ABC):\n    @abstractmethod\n    def calcular_area_total(self):\n        pass\nclass Casa(Edificio):\n    def __init__(self, ancho, alto):\n        self.ancho = ancho\n        self.alto = alto\n    def calcular_area_total(self):\n        return self.ancho * self.alto\nclass Apartamento(Edificio):\n    def __init__(self, ancho, alto):\n        self.ancho = ancho\n        self.alto = alto\n    def calcular_area_total(self):\n        return self.ancho * self.alto"
            },
            {
                "exercise": "Crea una clase abstracta 'Instrumento' con un método abstracto 'tocar'. Crea subclases 'Piano' y 'Guitarra' que implementen este método.",
                "solution": "from abc import ABC, abstractmethod\nclass Instrumento(ABC):\n    @abstractmethod\n    def tocar(self):\n        pass\nclass Piano(Instrumento):\n    def tocar(self):\n        return 'Sonido del piano'\nclass Guitarra(Instrumento):\n    def tocar(self):\n        return 'Sonido de la guitarra'"
            },
            {
                "exercise": "Crea una clase abstracta 'Cuenta' con un método abstracto 'retirar_dinero'. Luego, implementa subclases 'CuentaCorriente' y 'CuentaAhorro'.",
                "solution": "from abc import ABC, abstractmethod\nclass Cuenta(ABC):\n    @abstractmethod\n    def retirar_dinero(self, cantidad):\n        pass\nclass CuentaCorriente(Cuenta):\n    def retirar_dinero(self, cantidad):\n        return f'Retirando {cantidad} de cuenta corriente'\nclass CuentaAhorro(Cuenta):\n    def retirar_dinero(self, cantidad):\n        return f'Retirando {cantidad} de cuenta de ahorro'"
            },
            {
                "exercise": "Define una clase abstracta 'Tarea' con un método abstracto 'ejecutar'. Crea subclases 'TareaDeLimpieza' y 'TareaDeCocina'.",
                "solution": "from abc import ABC, abstractmethod\nclass Tarea(ABC):\n    @abstractmethod\n    def ejecutar(self):\n        pass\nclass TareaDeLimpieza(Tarea):\n    def ejecutar(self):\n        return 'Ejecutando tarea de limpieza'\nclass TareaDeCocina(Tarea):\n    def ejecutar(self):\n        return 'Ejecutando tarea de cocina'"
            },
            {
                "exercise": "Implementa una clase abstracta 'SistemaOperativo' con un método abstracto 'instalar_programa'. Luego, crea subclases 'Windows' y 'Linux'.",
                "solution": "from abc import ABC, abstractmethod\nclass SistemaOperativo(ABC):\n    @abstractmethod\n    def instalar_programa(self, programa):\n        pass\nclass Windows(SistemaOperativo):\n    def instalar_programa(self, programa):\n        return f'Instalando {programa} en Windows'\nclass Linux(SistemaOperativo):\n    def instalar_programa(self, programa):\n        return f'Instalando {programa} en Linux'"
            }
        ]

    def ask_exercise(self, exercise_type):
        if exercise_type == "encapsulamiento":
            exercise_data = random.choice(self.encapsulamiento_exercises)
        else:
            exercise_data = random.choice(self.abstraccion_exercises)

        user_solution = input(f"Ejercicio: {exercise_data['exercise']} \nEscribe tu solución:\n")

        if user_solution.strip() == exercise_data['solution'].strip():
            print("¡Correcto!")
        else:
            print("Incorrecto. Aquí está una posible solución:\n", exercise_data["solution"])
            self.ask_similar_exercise(exercise_data["exercise"], exercise_type)

    def ask_similar_exercise(self, original_exercise, exercise_type):
        similar_exercises = [
            "Modifica el ejercicio anterior para agregar un método adicional.",
            "Crea un ejercicio que use un atributo adicional.",
            "Crea una clase relacionada que implemente características similares.",
        ]

        new_exercise = random.choice(similar_exercises)
        user_solution = input(f"Ejercicio similar: {new_exercise} \nEscribe tu solución:\n")
        print("Gracias por tu respuesta.")

def main():
    teacher = SilentTeacher()
    while True:
        exercise_type = input("¿Qué tipo de ejercicio quieres resolver? (encapsulamiento/abstracción): ")
        if exercise_type in ["encapsulamiento", "abstracción"]:
            teacher.ask_exercise(exercise_type)
        else:
            print("Tipo de ejercicio no válido.")

        continue_game = input("¿Quieres resolver otro ejercicio? (s/n) ")
        if continue_game.lower() != 's':
            break

if __name__ == "__main__":
    main()
# Out:
# ¿Qué tipo de ejercicio quieres resolver? (encapsulamiento/abstracción): encapsulamiento
